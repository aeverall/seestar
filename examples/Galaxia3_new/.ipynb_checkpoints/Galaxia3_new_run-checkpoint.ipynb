# %%
# autoreload modules when files have been altered
# %load_ext autoreload
# %autoreload 2

import os, sys, time
import numpy as np
import pandas as pd

# %matplotlib inline
import matplotlib.pyplot as plt

sys.path.append("/home/andy/Documents/Research/SF/GitRepo/seestar/")
import SelectionGrid
import IsochroneScaling
import ArrayMechanics
#from seestar import ArrayMechanics
#from seestar import SelectionGrid

import seaborn as sns
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from seestar import surveyInfoPickler
fileinfo = surveyInfoPickler.surveyInformation('/media/andy/37E3-0F91/Research/SF/SFdata/Galaxia3_new/Galaxia3_new_fileinfo.pickle')
fileinfo.spectro_model = ('GMM', 1)
fileinfo.photo_model = ('GMM', 2)
#fileinfo.photo_coords = ['glon', 'glat', 'Japp', 'Kapp', 'Happ']
fileinfo.save()

# %%
fileinfo_path = '/media/andy/37E3-0F91/Research/SF/SFdata/Galaxia3_new/Galaxia3_new_fileinfo.pickle'
SF = SelectionGrid.SFGenerator(fileinfo_path, ncores=3)
# Out:
# Would you like the selection function in: a) observable, b) intrinsic, c) both? (return a, b or c)a
# Path to observable SF (Galaxia3_new_obsSF.pickle) exists. Use this to ? (y/n)n
# The spectro model description is:('GMM', 1)
# The photo model description is:('GMM', 2)
#
# {'glon': 'phi', 'Colmin': 'Colmin', 'glat': 'theta', 'Colmax': 'Colmax', 'Magmin': 'Magmin', 'Magmax': 'Magmax', 'fieldID': 'fieldID', 'halfangle': 'halfangle'}
# Importing data for Colour-Magnitude Field interpolants...
# {'Kapp': 'appB', 'Happ': 'appC', 'glon': 'phi', 'glat': 'theta', 'Japp': 'appA', 'fieldID': 'fieldID'}
# Filtering for null values in spectro: Total star count = 5847. Filtered star count = 5847. 0 stars removed with null values
# ((8.001017701622784, 13.499959932502573), (0.5000188162888577, 1.1835355696129728))
# ...done.
#
# Creating Colour-Magnitude Field interpolants...
# multiprocessing - observable SF calculation - running on 3 cores...
# Current field in col-mag calculation: 1.0, 1/3, Time: 1m, Left: 0m
# now pickling them...
# ...done
# .
# 81.4580380917

# %% [markdown]
# # Calculate union for set of stars

# %%
IsoCalculator = IsochroneScaling.IntrinsicToObservable()
IsoCalculator.LoadColMag(SF.isocolmag_pickle)

# %%
from seestar import surveyInfoPickler
fileinfo = surveyInfoPickler.surveyInformation('/media/andy/37E3-0F91/Research/SF/SFdata/Galaxia3_new/Galaxia3_new_fileinfo.pickle')

# %%
survey = pd.read_csv(fileinfo.spectro_path)
#survey = survey[(survey[fileinfo.spectro_coords[0]].apply(lambda a: a in fields))]
survey['Colour'] = survey[fileinfo.spectro_coords[3]] - survey[fileinfo.spectro_coords[4]]
# Recalculate to make colour and apparent magnitude agree
survey['Colour'], survey['Happ'] = IsoCalculator.ColourMapp(survey.ageGyr, survey.mh, survey.mass, survey.s)

survey1 = survey[survey[fileinfo.spectro_coords[0]] == 1.0]
survey23 = survey[survey[fileinfo.spectro_coords[0]].apply(lambda x: x in [2.0,3.0])]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-b9a6d8feb750> in <module>()
#       3 survey['Colour'] = survey[fileinfo.spectro_coords[3]] - survey[fileinfo.spectro_coords[4]]
#       4 # Recalculate to make colour and apparent magnitude agree
# ----> 5 survey['Colour'], survey['Happ'] = IsoCalculator.ColourMapp(survey.ageGyr, survey.mh, survey.mass, survey.s)
#       6
#       7 survey1 = survey[survey[fileinfo.spectro_coords[0]] == 1.0]
#
# NameError: name 'IsoCalculator' is not defined

# %%
full1 = pd.read_csv(os.path.join(fileinfo.photo_path, str(1.0))+'.csv')
full1['Colour'] = full1[fileinfo.photo_coords[2]]-full1[fileinfo.photo_coords[3]]
full1.rename(index=str, columns={'feh':'mh', 'smass':'mass','rad':'s'}, inplace=True)
full1['Colour'], full1['Happ'] = IsoCalculator.ColourMapp(full1.ageGyr, full1.mh, full1.mass, full1.s)

# %%
full1 = SF(full1, method='intrinsic', coords=['ageGyr', 'mh', 's', 'mass'], angle_coords=['glon', 'glat'])
full1['union_int'] = full1.union
# Out:
# Calculating all SF values...
# 0...0/14566...done
# Calculating union contribution...
# ...done

# %%
full1 = SF(full1, method='observable', coords=['Happ', 'Colour'], angle_coords=['glon', 'glat'])
full1['union_obs'] = full1.union
# Out:
# Calculating all SF values...
# ...Assigning: 1969303/1969303
# Calculating: 1804476/1969303
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-027b85e40e20> in <module>()
# ----> 1 full1 = SF(full1, method='observable', coords=['Happ', 'Colour'], angle_coords=['glon', 'glat'])
#       2 full1['union_obs'] = full1.union
#
# /home/andy/Documents/Research/SF/GitRepo/seestar/SelectionGrid.py in __call__(self, catalogue, method, coords, angle_coords, rng_phi, rng_th)
#     242             catalogue = FieldUnions.GenerateMatrices(catalogue, self.pointings,
#     243                                                     angle_coords, point_coords, 'halfangle',
# --> 244                                                     SFcalc, IDtype=self.fieldlabel_type)
#     245             print('...done')
#     246
#
# /home/andy/anaconda2/lib/python2.7/site-packages/seestar-1.2.7rc0-py2.7.egg/seestar/FieldUnions.pyc in GenerateMatrices(df, pointings, angle_coords, point_coords, halfangle, SFcalc, IDtype, Nsample, test, progress)
#     233
#     234         # zip datatypes together - tupes of (sf, field)
# --> 235         field_info = [list(zip(SFprob.SFprob.iloc[i], dfi.points.iloc[i])) for i in range(len(dfi))]
#     236         field_info = pd.DataFrame(pd.Series(field_info), columns=['field_info'])
#     237
#
# /home/andy/anaconda2/lib/python2.7/site-packages/pandas/core/indexing.pyc in __getitem__(self, key)
#    1326         else:
#    1327             key = com._apply_if_callable(key, self.obj)
# -> 1328             return self._getitem_axis(key, axis=0)
#    1329
#    1330     def _is_scalar_access(self, key):
#
# /home/andy/anaconda2/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_axis(self, key, axis)
#    1747
#    1748             # validate the location
# -> 1749             self._is_valid_integer(key, axis)
#    1750
#    1751             return self._get_loc(key, axis=axis)
#
# /home/andy/anaconda2/lib/python2.7/site-packages/pandas/core/indexing.pyc in _is_valid_integer(self, key, axis)
#    1634
#    1635         ax = self.obj._get_axis(axis)
# -> 1636         l = len(ax)
#    1637         if key >= l or key < -l:
#    1638             raise IndexError("single positional indexer is out-of-bounds")
#
# /home/andy/anaconda2/lib/python2.7/site-packages/pandas/core/indexes/range.pyc in __len__(self)
#     444                                             sort)
#     445
# --> 446     def __len__(self):
#     447         """
#     448         return the length of the RangeIndex
#
# KeyboardInterrupt:

# %%
full23 = pd.DataFrame()
fields= [2.0,3.0]
for field in fields:
    full23 = pd.concat((full23, pd.read_csv(os.path.join(fileinfo.photo_path, str(field))+'.csv')))
full23['Colour'] = full23[fileinfo.photo_coords[2]]-full23[fileinfo.photo_coords[3]]
full23.rename(index=str, columns={'feh':'mh', 'smass':'mass','rad':'s'}, inplace=True)
# Recalculate to make colour and apparent magnitude agree
full23['Colour'], full23['Happ'] = IsoCalculator.ColourMapp(full23.ageGyr, full23.mh, full23.mass, full23.s)

# %%
full23 = SF(full23, method='intrinsic', coords=['ageGyr', 'mh', 's', 'mass'], angle_coords=['glon', 'glat'])
full23['union_int'] = full23.union
# Out:
# Calculating all SF values...
# 0...0/14566...done
# Calculating union contribution...
# ...done

# %%
full23 = SF(full23, method='observable', coords=['Happ', 'Colour'], angle_coords=['glon', 'glat'])
full23['union_obs'] = full23.union
# Out:
# Calculating all SF values...
# ...14566/14566        ...done
# Calculating union contribution...
# ...done

# %%
# Clear duplicates
cleared = pd.DataFrame()
for i in range(len(full23)):
    result = np.sum((full23[i+1:].glon == full23.iloc[i].glon)&\
                    (full23[i+1:].glat == full23.iloc[i].glat))
    if result == 0: cleared = pd.concat((cleared, full23[i:i+1]))
    sys.stdout.write('\rDuplicate progress: %d / %d' % (i, len(full23)))

full23_c = cleared
# Out:
# Duplicate progress: 14565 / 14566

# %%
cleared = pd.DataFrame()
for i in range(len(survey23)):
    result = np.sum((survey23[i+1:].glon == survey23.iloc[i].glon)&\
                    (survey23[i+1:].glat == survey23.iloc[i].glat))
    if result == 0: cleared = pd.concat((cleared, survey23[i:i+1]))
    sys.stdout.write('\rDuplicate progress: %d / %d' % (i, len(survey23)))
    
survey23_c = cleared
# Out:
# Duplicate progress: 244 / 245

# %%
len(full23), len(full23_c), len(survey23), len(survey23_c)
# Out:
# (14566, 9536, 245, 239)

# %%
full1.to_csv(os.path.join(fileinfo.photo_path, 'solutionF1.csv'), index=False)
full23.to_csv(os.path.join(fileinfo.photo_path, 'solutionF23.csv'), index=False)
survey1.to_csv(os.path.join(fileinfo.photo_path, 'solutionS1.csv'), index=False)
survey23.to_csv(os.path.join(fileinfo.photo_path, 'solutionS23.csv'), index=False)

full23_c.to_csv(os.path.join(fileinfo.photo_path, 'solutionF23_c.csv'), index=False)
survey23_c.to_csv(os.path.join(fileinfo.photo_path, 'solutionS23_c.csv'), index=False)

# %%
full1 = pd.read_csv(os.path.join(fileinfo.photo_path, 'solutionF1.csv'))
full23 = pd.read_csv(os.path.join(fileinfo.photo_path, 'solutionF23.csv'))
survey1 = pd.read_csv(os.path.join(fileinfo.photo_path, 'solutionS1.csv'))
survey23 = pd.read_csv(os.path.join(fileinfo.photo_path, 'solutionS23.csv'))

# %%
full23.head()
# Out:
#        fieldID    ageGyr        mh      mass         s      glat      glon  \
# index
# 0            0  0.146550  0.024854  0.118094  0.050557  1.031251  0.503301
# 1            0  0.046584 -0.086393  0.103889  0.088312  1.065937  0.579193
# 2            0  0.149308 -0.053664  0.134221  0.107869  1.046676  0.549127
# 3            0  0.086754 -0.154071  0.167904  0.090879  1.050701  0.589668
# 4            0  0.136860  0.052209  0.189273  0.115518  1.064732  0.463338
#
#             Japp       Kapp       Happ    Colour      points  \
# index
# 0      12.750265  11.980913  12.213223  0.769352  [2.0, 3.0]
# 1      13.327351  12.549949  12.783145  0.777403  [2.0, 3.0]
# 2      14.178272  13.400935  13.629931  0.777336  [2.0, 3.0]
# 3      13.086758  12.330495  12.529782  0.756263       [2.0]
# 4      13.671784  12.906952  13.115868  0.764832  [2.0, 3.0]
#
#                                  SFprob  \
# index
# 0      [0.584637634855, 0.614999887478]
# 1      [0.544368037454, 0.597956103192]
# 2                            [0.0, 0.0]
# 3                      [0.691477972588]
# 4       [0.565791774822, 0.60074554748]
#
#                                            field_info     union  union_int
# index
# 0      [(0.584637634855, 2.0), (0.614999887478, 3.0)]  0.840085   0.840085
# 1      [(0.544368037454, 2.0), (0.597956103192, 3.0)]  0.816816   0.816816
# 2                            [(0.0, 2.0), (0.0, 3.0)]  0.000000   0.000000
# 3                             [(0.691477972588, 2.0)]  0.691478   0.691478
# 4       [(0.565791774822, 2.0), (0.60074554748, 3.0)]  0.826640   0.826640

# %%
full23.points.iloc[0]
# Out:
# [2.0, 3.0]

# %% [markdown]
# ## Plot results

# %%
# Plots for each of the 4 quantities

def HistogramValues(cat, label, nbin=20, rng=(0,1),
                   lweight='', weighted=False):   

    if  weighted: 
        density, val = np.histogram(cat[label], weights=cat[lweight], bins=nbin, range=rng)
        N = np.sum(cat[lweight])
    else: 
        density, val = np.histogram(cat[label], bins=nbin, range=rng)
        N = float(len(cat))
        
    centers = ArrayMechanics.BoundaryToCentre(val)
    
    return density/N, centers


# Plots for each of the 4 quantities

def CDFValues(cat, label, nbin=20, rng=(0,1),
                   lweight='', weighted=False):   

    if  weighted: 
        density, val = np.histogram(cat[label], weights=cat[lweight], bins=nbin, range=rng)
        N = np.sum(cat[lweight])
    else: 
        density, val = np.histogram(cat[label], bins=nbin, range=rng)
        N = float(len(cat))
        
    centers = ArrayMechanics.BoundaryToCentre(val)
    
    density = density/N
    cdf = np.zeros(len(density))
    for i in range(len(density)):
        cdf[i] = np.sum(density[:i])
    
    return cdf, centers

# %%
fig = plt.figure(figsize=(20, 20))

#full['union'] = full['union_obs']
#full = full[pd.notnull(full.union)]
#full = full3[~np.isnan(full3.union)]
full = full1
survey = survey1

nbin=50

ax1 = plt.subplot(221)
age_d, age = HistogramValues(full, 'ageGyr', nbin=nbin, rng=(0, 13))
_=plt.plot(age, age_d, label='full', linewidth=2.)
age_d, age = HistogramValues(survey, 'ageGyr', nbin=nbin, rng=(0, 13))
_=plt.plot(age, age_d, label='selected', linewidth=2.)
age_d, age = HistogramValues(full, 'ageGyr', nbin=nbin, rng=(0, 13), weighted=True, lweight='union')
_=plt.plot(age, age_d, label='weighted', linewidth=2.)
ax1.set_xlabel(r"$\tau$")
ax1.set_ylabel('Normalised count')

ax2 = plt.subplot(222)
mh_d, mh = HistogramValues(full, 'mh', nbin=nbin, rng=(-2,1.5))
_=plt.plot(mh, mh_d, label='full', linewidth=2.)
mh_d, mh = HistogramValues(survey, 'mh', nbin=nbin, rng=(-2,1.5))
_=plt.plot(mh, mh_d, label='selected', linewidth=2.)
mh_d, mh = HistogramValues(full, 'mh', nbin=nbin, rng=(-2,1.5), weighted=True, lweight='union')
_=plt.plot(mh, mh_d, label='weighted', linewidth=2.)
ax2.set_xlabel('[M/H]')

ax3 = plt.subplot(223)
ms_d, ms = HistogramValues(full, 'mass', nbin=nbin, rng=(0,4))
_=plt.plot(ms, ms_d, label='full', linewidth=2.)
ms_d, ms = HistogramValues(survey, 'mass', nbin=nbin, rng=(0,4))
_=plt.plot(ms, ms_d, label='selected', linewidth=2.)
age_d, age = HistogramValues(full, 'mass', nbin=nbin, rng=(0, 4), weighted=True, lweight='union')
_=plt.plot(age, age_d, label='weighted', linewidth=2.)
ax3.set_xlabel(r'$m_s$')
ax3.set_ylabel('Normalised count')

ax4 = plt.subplot(224)
s_d, s = HistogramValues(full, 's', nbin=nbin, rng=(0,8))
_=plt.plot(s, s_d, label='full', linewidth=2.)
s_d, s = HistogramValues(survey, 's', nbin=nbin, rng=(0,8))
_=plt.plot(s, s_d, label='selected', linewidth=2.)
s_d, s = HistogramValues(full, 's', nbin=nbin, rng=(0,8), weighted=True, lweight='union')
_=plt.plot(s, s_d, label='weighted', linewidth=2.)
ax4.set_xlabel(r'$s$')
plt.legend()

#fig.savefig('../../SFProject/WriteUp/PaperFigs/Galaxia3_fullvsselected_intrinsic_overlapping.png', bbox_inches='tight')
#fig.savefig('../../SFProject/WriteUp/PaperFigs/Galaxia3_fullvsselected_intrinsic_planefield.png', bbox_inches='tight')
#fig.savefig('../../SFProject/WriteUp/PaperFigs/Galaxia3_fullvsselected_intrinsic.png', bbox_inches='tight')

# %%
# Distribution in colour-magnitude space

fig = plt.figure(figsize=(20, 10))

ax1 = plt.subplot(121)
mag_d, mag = HistogramValues(full, 'Happ', nbin=30, rng=(6, 15))
_=plt.plot(mag, mag_d, label='full', linewidth=2.)
mag_d, mag = HistogramValues(survey, 'Happ', nbin=30, rng=(6, 15))
_=plt.plot(mag, mag_d, label='selected', linewidth=2.)
mag_d, mag = HistogramValues(full, 'Happ', nbin=30, rng=(6, 15), weighted=True, lweight='union')
_=plt.plot(mag, mag_d, label='weighted', linewidth=2.)
ax1.set_xlabel(r"$m_H$")
ax1.set_ylabel('Normalised count')

ax2 = plt.subplot(122)
col_d, col = HistogramValues(full, 'Colour', nbin=30, rng=(0.2, 1.2))
_=plt.plot(col, col_d, label='full', linewidth=2.)
col_d, col = HistogramValues(survey, 'Colour', nbin=30, rng=(0.2, 1.2))
_=plt.plot(col, col_d, label='selected', linewidth=2.)
col_d, col = HistogramValues(full, 'Colour', nbin=30, rng=(0.2, 1.2), weighted=True, lweight='union')
_=plt.plot(col, col_d, label='weighted', linewidth=2.)
ax2.set_xlabel('$M_J - M_K$')
plt.legend()
#fig.savefig('../../SFProject/WriteUp/PaperFigs/Galaxia3_fullvsselected_intrinsic.png', bbox_inches='tight')

# %%
# field 1

# %% [markdown]
# # KDE plots

# %%
def kde(df, survey, coord, ax, xlabel={}, xlim={}, fs=35, legend=True,
        label1=r'$f_\mathrm{DF}(\mathbf{v} \,|\,\Theta_1)$',
        label2=r'$f_\mathrm{Obs}(\mathbf{v} \,|\,\Theta_1)$',
        label3=r'$f_\mathrm{DF}(\mathbf{v} \,|\,\Theta_1) \times \mathrm{P}(\mathrm{S}\,|\,\mathbf{v}, \Theta_1)$'
       ):


    
    plt.sca(ax)

    sns.kdeplot(df[coord], label=label1, alpha=1., c='r', legend=legend)
    sns.kdeplot(survey[coord], label=label2, alpha=1., c='g', legend=legend)

    N=10
    for i in range(N):
        df_rand = df[np.random.rand(len(df)) < df.union][[coord]].copy()

        kwargs = {'alpha':0.1, 'color':'b'}
        if i==0: labelargs = {'label':label3,\
                              'legend':legend}
        else: labelargs = {'legend':False}
        kwargs.update(labelargs)
        sns.kdeplot(df_rand[coord], **kwargs)

    plt.xlim(xlim[coord])
    plt.xlabel(xlabel[coord], fontsize=fs)
    plt.ylabel(ylabel[coord], fontsize=fs)
    if legend: plt.setp(ax.get_legend().get_texts(), fontsize=fs) 

    plt.tick_params('both', labelsize=20)

# %%
fig, ax = plt.subplots(2, 2, figsize=(20,20))

xlabel = {'mass':r'$\mathcal{M}$ ($\mathrm{M}_\odot$)', 'ageGyr':r'$\tau$ (Gyr)', \
          'mh':r'[M/H] (dex)','s':r'$s$ (kpc)'}
ylabel = {'mass':r'PDF ($\mathrm{M}_\odot^{-1}$)', 'ageGyr':r'PDF ($\mathrm{Gyr}^{-1}$)',\
          'mh':r'PDF ($\mathrm{dex}^{-1}$)', 's':r'PDF ($\mathrm{kpc}^{-1}$)'}
xlim = {'mass':(0,4), 'ageGyr':(0,13), 'mh':(-1.5, 1.0), 's':(0,16)}
coords = ['ageGyr', 'mh', 'mass', 's']

label1=r'$f_\mathrm{DF}(\mathbf{v} \,|\,\Theta_2 \cup \Theta_3)$'
label2=r'$f_\mathrm{Obs}(\mathbf{v} \,|\,\Theta_2 \cup \Theta_3)$'
label3=r'$f_\mathrm{DF}(\mathbf{v} \,|\,\Theta_2 \cup \Theta_3) \times \mathrm{P}(\mathrm{S}\,|\,\mathbf{v}, \Theta_2 \cup \Theta_3)$'

kwargs = {'xlabel':xlabel, 'xlim':xlim, 'fs':20, 'label1':label1, 'label2':label2, 'label3':label3}

kde(full23_c, survey23_c, coords[0], ax[0,0], **kwargs)
kde(full23_c, survey23_c, coords[1], ax[0,1], legend=False, **kwargs)
kde(full23_c, survey23_c, coords[2], ax[1,0], legend=False, **kwargs)
kde(full23_c, survey23_c, coords[3], ax[1,1], legend=False, **kwargs)

#plt.savefig('/home/andy/Documents/Research/SF/WriteUp/SFpaperGit/PaperFigs/G3_intrinsickdes_rand23.png', bbox_inches='tight')

# %%
plt.figure(figsize=(20, 20))

df_age = full[['mass', 'union']].copy()

nbin = 50

N=30
for i in range(N):
    df_rand = df_age[np.random.rand(len(df_age)) < df_age.union].copy()
    
    age_d, age = HistogramValues(df_rand, 'mass', nbin=nbin, rng=(0, 4))
    kwargs = {'linewidth':2., 'alpha':0.1, 'c':'b'}
    if i==0: kwargs['label']='reweighted'
    plt.plot(age, age_d, **kwargs)#label='reweighted', linewidth=2., alpha=0.1, c='b')
    
age_d, age = HistogramValues(full, 'mass', nbin=nbin, rng=(0, 4))
plt.plot(age, age_d, label='fulldf', linewidth=2., alpha=1., c='r')

age_d, age = HistogramValues(survey, 'mass', nbin=nbin, rng=(0, 4))
plt.plot(age, age_d, label='survey', linewidth=2., alpha=1., c='g')

plt.legend()
