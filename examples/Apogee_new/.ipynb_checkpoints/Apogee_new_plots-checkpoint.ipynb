# %%
# autoreload modules when files have been altered
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd
import dill

# %matplotlib inline
from matplotlib import pyplot as plt
import matplotlib
from matplotlib.colors import LogNorm
font = {'family' : 'serif', 'weight':'normal',
        'size'   : 30}
matplotlib.rc('font', **font)

import seaborn as sns
rc={'font.size': 16, 'axes.labelsize': 16, 'legend.fontsize': 12,
    'axes.titlesize': 18, 'xtick.labelsize': 12, 'ytick.labelsize': 12}
sns.set(font="serif",style="white",rc=rc)

def ErrorWarning():
    raise ValueError("Wait, don't run this, you don't want to!")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from seestar import surveyInfoPickler

# %%
fileinfo = surveyInfoPickler.surveyInformation('/media/andy/37E3-0F91/Research/SF/SFdata/Apogee_new/Apogee_new_fileinfo.pickle')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-89b69065b078> in <module>()
# ----> 1 fileinfo = surveyInfoPickler.surveyInformation('/media/andy/37E3-0F91/Research/SF/SFdata/Apogee_new/Apogee_new_fileinfo.pickle')
#
# ~/anaconda2/envs/py35/lib/python3.5/site-packages/seestar-1.0-py3.5.egg/seestar/surveyInfoPickler.py in __init__(self, path, locQ)
#     136         if path is not None:
#     137             path = os.path.abspath(path)
# --> 138             self.load(path, locQ=locQ)
#     139
#     140     def __call__(self):
#
# ~/anaconda2/envs/py35/lib/python3.5/site-packages/seestar-1.0-py3.5.egg/seestar/surveyInfoPickler.py in load(self, filename, locQ)
#     208         # Load pickled dictionary of attributes
#     209         with open(filename, "rb") as f:
# --> 210             file_dict  = pickle.load(f)
# ...

# %% [markdown]
# # APOGEE fields

# %%
import sys
#from seestar import AngleDisks

# %%
sys.path.append('/home/andy/Documents/Research/SF/GitRepo/seestar/')
import AngleDisks
import matplotlib

# %%
# Field locations
fields = pd.read_csv('/media/andy/37E3-0F91/Research/SF/SFdata/Apogee_new/Apogee_new_fieldinfo.csv')

# %%
matplotlib.rcParams.update({'font.size': 40})

# %%
AngleDisks.PlotPlate(fields.glon, fields.glat, 7)
#plt.savefig('/home/andy/Documents/Research/SF/WriteUp/SFpaperGit/PaperFigs/ApogeeFieldsDR14.png', bbox_inches='tight')
#matplotlib.axes.Axes.tick_params('both', labelsize=100)
# Out:
# /home/andy/anaconda2/envs/py35/lib/python3.5/site-packages/matplotlib/projections/geo.py:485: RuntimeWarning: invalid value encountered in arcsin
#   theta = np.arcsin(y / np.sqrt(2))

# %% [markdown]
# # Field Overlap
